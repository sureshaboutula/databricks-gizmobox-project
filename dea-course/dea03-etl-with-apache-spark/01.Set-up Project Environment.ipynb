-- %% [markdown]
-- ## Set-up the Project Environment for Gizmobox Data Lakehouse

-- %% [markdown]
-- ### 1. Access the Container gizmobox - Before giving access. It should throw error

-- %%
%fs ls 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net'

-- %% [markdown]
-- ### 2. Create External location

-- %%
create external location `dea-course-dbr-dev_gizmobox`
  url 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/'
  with (storage credential dea_course_ext_sc)
  comment 'External Location for the Gizmobox Data Lakehouse'

-- %% [markdown]
-- ### 3. Access the Container gizmobox - After giving access. It should work

-- %%
%fs ls 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net'

-- %%
%fs ls 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/landing/'

-- %%
%fs ls 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/landing/operational_data/'

-- %%
%fs ls 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/landing/external_data/'

-- %% [markdown]
-- ### 4. Create the catalog - gizmobox

-- %%
show catalogs;

-- %%
create catalog if not exists gizmobox
  managed location 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/'
  comment 'This is the Catalog for Gizmobox Data Lakehouse';

-- %%
show catalogs;

-- %% [markdown]
-- ### 5. Create Schemas
-- - Landing
-- - Bronze
-- - Silver
-- - Gold

-- %%
select current_catalog();

-- %%
use catalog gizmobox;

-- %%
select current_catalog();

-- %%
create schema if not exists landing
  managed location 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/landing/';

-- %%
show schemas;

-- %%
create schema if not exists bronze
  managed location 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/bronze/';

create schema if not exists silver
  managed location 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/silver/';

create schema if not exists gold
  managed location 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/gold/';

-- %%
show schemas;

-- %% [markdown]
-- ### 6. Create Volume

-- %%
use catalog gizmobox;
use schema landing;

create external volume if not exists operational_data
  location 'abfss://gizmobox@deacourseextdldev.dfs.core.windows.net/landing/operational_data/';

-- %%
%fs ls /Volumes/gizmobox/landing/operational_data
