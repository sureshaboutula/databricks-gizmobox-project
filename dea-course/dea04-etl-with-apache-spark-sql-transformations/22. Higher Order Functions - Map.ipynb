-- %% [markdown]
-- # Higher Order Map Functions

-- %% [markdown]
-- A map is a collection key-value pairs like a dictionary
-- {'laptop': 1200, 'phone': 699}

-- %% [markdown]
-- ### Commonly Used higher order functions
-- 	- Transform_values
-- 	- Transform_keys
-- 	- Map_filter

-- %% [markdown]
-- ### Syntax
-- Function_name (map_column, lambda expression)
-- lambda expression: (key, value) -> expression

-- %%
create or replace temp view order_item_prices
as
select * from values
(1, map('smartphone', 699, 'laptop', 1199, 'monitor', 399)),
(2, map('tablet', 599, 'headphones', 199, 'smartwatch', 299)),
(3, map('keyboard', 89, 'mouse',59))
as orders(order_id, item_prices);

-- %%
select * 
from order_item_prices;

-- %% [markdown]
-- ### 1. Convert all the item names to be uppercase (transform_keys function)

-- %%
select order_id,
transform_keys(item_prices, (item, price) -> upper(item)) as items_upper_case
from order_item_prices;

-- %% [markdown]
-- ### 2. Apply 10% tax to each item prices (transform_values function)

-- %%
select order_id,
transform_values(item_prices, (item, price) -> round(price*1.10, 2)) as price_with_tax
from order_item_prices;

-- %% [markdown]
-- ### 3. Filter Only items with price above $500 (map_filter function)

-- %%
select order_id,
map_filter(item_prices, (item, price) -> price > 500) as premium_items
from order_item_prices;
